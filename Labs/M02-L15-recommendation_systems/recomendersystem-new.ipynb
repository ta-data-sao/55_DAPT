# %% [markdown]
# # Introdução a Sistemas de Recomendação
#
# Usaremos um dataset com as compras dos clientes de um mercado. Buscaremos padrões de compra semelhantes entre eles, a fim de gerar uma lista com 5 recomendações de produtos para cada cliente.

# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# ## Passo 1: crie um dataframe com a quantidade total de cada produto comprada por cada cliente.
#
# Precisaremos agrupar por `CustomerID` e `ProductName`, e então somar `Quantity`.

# %%
data=pd.read_csv('data/customer_product_sales.csv')
data.head()

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 2: use o método `pivot_table` para criar uma matriz `Produto X Cliente`.
#
# Cheque a documentação do método. As colunas da matriz devem representar os produtos; as linhas, os clientes; e os valores das células, as quantidades de cada produto compradas por cada cliente. Preencha valores nulos com `0`.

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 3: crie uma matriz de semelhança entre clientes, usando `squareform` e `pdist` (para o argumento de métrica de distância, use `euclidean`).
# _Dica1:_ lembre-se que similaridade é igual a `1 / (1 + distância)` - somamos 1 ao denominador para não gerar erros de divisão por 0.
#
# _Dica2:_ seu dataframe resultante deve ter 1000 linhas e 1000 colunas.

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 4: cheque seus resultados gerando uma lista com os 5 clientes mais parecidos com um `CustomerID` específico.

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 5: do dataframe criado no passo 1, selecione os registros de compras efetuadas por esses 5 clientes obtidos no passo 4.

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 6: agrupe esses registros de compras por `ProductName`, some `Quantity`, e então ordene-os decrescentemente por `Quantity`.
#
# Isso vai te dar a quantidade total de cada produto comprado pelos 5 clientes mais parecidos com o cliente escolhido, em ordem do mais comprado para o menos comprado.

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 7: filtre o dataframe, removendo produtos que nosso cliente específico já tenha comprado, e então recomende os 5 produtos com maior quantidade dentre os restantes.
#
# _Dica:_ você pode criar uma lista com os produtos já comprados pelo cliente específico e usá-la no filtro.

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 8: agora que geramos as recomendações para um cliente específico, junte as peças para gerar as recomendações para todos os clientes.
#
# - Crie um dicionário vazio que vai armazenar as recomendações (valores) para cada cliente (chaves).
# - Crie uma lista com os `CustomerID`s únicos para iterarmos.
# - Itere os passos de 4 a 7 na lista de clientes, acrescentando os resultados de cada iteração no dicionário.

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 9: armazene os resultados obtidos num dataframe (o dataframe deve ter 6 colunas - uma para `CustomerID` + 5 para os produtos recomendados para cada cliente).

# %%
# Seu código aqui

# %% [markdown]
# ## Passo 10: mude a métrica da distância usada no passo 3 para alguma outra que não euclidiana (`chebychev`, `correlation`, `cityblock`, `cosine`, `jaccard`, [etc](https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.pdist.html).), refaça as recomendações e perceba as diferenças.

# %%
# Seu código aqui
