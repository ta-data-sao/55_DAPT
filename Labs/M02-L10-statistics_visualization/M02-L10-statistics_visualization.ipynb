# %% [markdown]
# ![Ironhack logo](https://i.imgur.com/1QgrNNw.png)
# # LAB | Visualizando estatísticas
#
# ## Introdução
# Vamos usar datasets para ter um entendimento mais aprofundado sobre importantes distribuições de variáveis.
#
# Vamos entender como:
# - ter uma noção das distribuções estatísticas só por observar a descrição estatística dos valores numéricos do dataset
# - entender os efeitos de uma distribuição normal e de uma distribuição não-normal na análise de pontos fora da curva (outliers)
# - entender como uma variável pode impactar na distribuição de outra variável

# %% [markdown]
# ## Importar bibliotecas:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Ler o dataset em `weight-height-money.csv`:
#
# Dê uma olhada nas primeiras linhas do dataset.

# %%
# Seu código aqui

# %% [markdown]
# ## Use o método `.describe()` para entender os dados.

# %%
# Seu código aqui

# %% [markdown]
# ## O que você pode observar? Compare a média e a mediana de cada variável numérica do dataset.

# %%
# Seu código aqui

# %% [markdown]
# ## A partir dessa observação, o que você pode concluir? Você pode supor que tipo de distribuição tem cada variável?
#
# Tente prever qual tipo de distribuição cada variável apresenta (sem plotar ainda!):
# - Assimétrica negativa (cauda mais longa na esquerda)
# - Assimétrica positiva (cauda mais longa na direita)
# - Simétrica/normal/gaussiana
#
# _dica: Lembre-se dos efeitos de outliers nos valores da média e da mediana. Geralmente, a comparação entre esses dois valores já nos leva a percepções significativas a respeito da distribuição da variável. Se média e mediana estão próximas, você pode supor que a maior parte dos dados está concentrada numa região próxima à média. Entretanto, se média e mediana estão distantes uma da outra, você pode supor que algumas observações estão puxando a média para perto delas._

# %%
# Seu código aqui

# %% [markdown]
# # Análise univariada

# %% [markdown]
# ## Contagem de gênero
#
# Conte quantas observações de `Male` e de `Female` existem no dataset, usando pandas.

# %%
# Seu código aqui

# %% [markdown]
# ## Visualização da contagem de gênero
#
# Use seaborn (sns) para visualizar quantas ocorrências de `Male` e de `Female` existem no dataset.
#
# _dica: se você não sabe como fazer isso, jogue no google "seaborn" + "[o método de contagem do pandas]"_

# %%
# Seu código aqui

# %% [markdown]
# ## Considere somente a altura
#
# Crie uma série pandas com a variável `height` (altura).

# %%
# Seu código aqui

# %% [markdown]
# ### Plotagem de histograma
#
# Plote o histograma da variável `height`.

# %%
plt.figure(figsize=(12, 8))
# Seu código aqui

# %% [markdown]
# ### Diagrama de caixa (boxplot)
#
# Plote o boxplot da variável `height`.

# %%
plt.figure(figsize=(12, 8))
# Seu código aqui

# %% [markdown]
# O que você acha da distribuição das alturas? É comum variáveis se comportarem assim?

# %%
# Seu código aqui

# %% [markdown]
# ### Distribuição KDE da altura

# %% [markdown]
# Plote a distribuição kde (estimativa de densidade kernel) da variável `height` (sem o histograma).

# %%
# Seu código aqui

# %% [markdown]
# ### Análise

# %% [markdown]
# Como podemos observar, temos um grande número de pessoas com altura entre 60 e 75 polegadas. Quantas pessoas estão fora dos três desvios padrão a partir da média? Podemos considerá-las outliers? Por quê?

# %% [markdown]
# #### Calcule a média

# %%
# Seu código aqui

# %% [markdown]
# #### Calcule o desvio padrão

# %%
# Seu código aqui

# %% [markdown]
# #### Calcule os valores de corte:
#
# `corte_superior = média` <b><span style="color:red">+</span></b> `3 * desvio_padrão`
#
# `corte_inferior = média` <b><span style="color:red">-</span></b> `3 * desvio_padrão`

# %% [markdown]
# #### Agora, filtre o dataset original.
#
# Use os valores que você calculou acima para filtrar o dataset original.
#
# Você deve obter um dataset filtrado, contendo somente as linhas cujas alturas são maiores que o corte superior ou menores que o corte inferior.

# %%
# Seu código aqui

# %% [markdown]
# Resultados esperados:
#
# |      | Gender   |   Height |   Weight |        Money |
# |-----:|:---------|---------:|---------:|-------------:|
# |  994 | Male     |  78.0959 | 255.691  | 1357.11      |
# | 1317 | Male     |  78.4621 | 227.343  |    5.45797   |
# | 2014 | Male     |  78.9987 | 269.99   |  131.474     |
# | 3285 | Male     |  78.5282 | 253.889  |    0.0896631 |
# | 3757 | Male     |  78.6214 | 245.734  |  204.113     |
# | 6624 | Female   |  54.6169 |  71.3937 |  226.061     |
# | 9285 | Female   |  54.2631 |  64.7001 |  646.532     |

# %% [markdown]
# #### Enfim, calcule as dimensões deste dataset filtrado e compare com as dimensões do original.
#
# A que porcentagem do dataset original correspondem as alturas fora do intervalo de corte? Você esperava esse valor? Por quê?

# %%
# Seu código aqui

# %% [markdown]
# ## Agora, faça a mesma análise para a variável `money` (dinheiro).

# %% [markdown]
# Você fará exatamente a mesma análise para uma variável do dataset que apresenta aspectos diferentes. Vamos tentar entender isso.

# %% [markdown]
# ## Considere somente dinheiro.
#
# Crie uma série pandas a partir da variável `money`.

# %%
# Seu código aqui

# %% [markdown]
# Dimensão:

# %%
# Seu código aqui

# %% [markdown]
# ### Plotagem do histograma

# %%
# Seu código aqui

# %% [markdown]
# ### Boxplot

# %%
# Seu código aqui

# %% [markdown]
# ### Distribuição KDE de dinheiro

# %%
# Seu código aqui

# %% [markdown]
# ### Análise

# %% [markdown]
# Novamente, quantas pessoas estão fora do intervalo de três desvios padrão a partir da média? Qual porcentagem do dataset? Vamos por partes:

# %% [markdown]
# #### Calcule a média

# %%
# Seu código aqui

# %% [markdown]
# #### Calcule o desvio padrão

# %%
# Seu código aqui

# %% [markdown]
# #### Calcule os valores de corte:
#
# `corte_superior = média` <b><span style="color:red">+</span></b> `3 * desvio_padrão`
#
# `corte_inferior = média` <b><span style="color:red">-</span></b> `3 * desvio_padrão`

# %% [markdown]
# #### De novo, filtre o dataset original.

# %%
# Seu código aqui

# %% [markdown]
# #### Finalmente, calcule as dimensões do dataset filtrado e compare com as do dataset original.
#
# A que porcentagem correspondem os valores fora do intervalo de corte? Você esperava esse resultado?

# %%
# Seu código aqui

# %% [markdown]
# Resultado esperado:
#
# |     | Gender   |   Height |   Weight |   Money |
# |----:|:---------|---------:|---------:|--------:|
# | 234 | Male     |  67.3698 |  176.636 | 3725.08 |
# | 294 | Male     |  64.4252 |  169.109 | 3942.97 |
# | 355 | Male     |  72.9386 |  216.097 | 3762.42 |
# | 518 | Male     |  68.3465 |  178.676 | 3286.66 |
# | 662 | Male     |  69.431  |  172.326 | 3798.71 |
# |   ...   | ...   |   ... |   ... |   ... |
# | 9873 | Female   |  63.7072 |  132.761 | 3164.37 |
# | 9888 | Female   |  65.1059 |  149.695 | 3929.57 |
# | 9922 | Female   |  58.7525 |  106.846 | 3541.68 |
# | 9930 | Female   |  68.5444 |  148.828 | 3916.32 |
# | 9946 | Female   |  66.6245 |  149.828 | 6535.36 |

# %% [markdown]
# Você pode os considerar outliers?

# %%
# Seu código aqui

# %% [markdown]
# A esta altura, você deve ter percebido que, para considerarmos uma observação como `outlier`, precisamos primeiro avaliar a **distribuição** da variável. Na verdade, a maioria dos aspectos estatísticos não significam nada antes de entendermos a distribuição da variável...

# %% [markdown]
# # Análise bivariada

# %% [markdown]
# ## Considerando altura e peso
#
# Agora, iremos considerar tanto a variável `height` (altura) quanto a `weight` (peso), para entender nossos dados. Vamos performar o que chamamos de análise bivariada.

# %% [markdown]
# ### Plote um gráfico de dispersão (scatterplot) para visualizar a relação entre altura e peso

# %%
plt.figure(figsize=(12, 8))
# Seu código aqui

# %% [markdown]
# ### Repita o mesmo gráfico, mas acrescente marcadores de cor de acordo com `gender` (gênero)

# %%
plt.figure(figsize=(12, 8))
# Seu código aqui

# %% [markdown]
# ### Colorir o gráfico através da variável gênero te trouxe percepções significativas? Quais?

# %%
# Seu código aqui

# %% [markdown]
# ### Crie uma variável chamada `groupby_genero` para agrupar os dados por `Gender` (gênero). Mas não defina nenhuma agregação ainda!
#
# Apenas performe a operação `.groupby()`

# %%
# Seu código aqui

# %% [markdown]
# #### Rode `groupby_genero.head()` para conferir os grupos obtidos.

# %%
# Seu código aqui

# %% [markdown]
# #### Rode `groupby_genero.describe()` para conferir as estatísticas de cada grupo.
#
# _dica: você pode transpor a tabela estatística para uma melhor visualização dos resultados_

# %%
# Seu código aqui

# %% [markdown]
# Os resultados acima deveriam te trazer algumas percepções sobre o efeito de gênero nos dados...

# %% [markdown]
# ## Plotagem de distribuições

# %% [markdown]
# ### Verificando a distribuição das variáveis de acordo com gênero.
#
# Percebemos que cada variável no dataset tem seu próprio "dna", isto é, sua distribuição. Entretanto, a história não para aí... Cada variável tem suas peculiaridades e é nosso trabalho enquanto analistas de dados identificá-las. Perceberemos, em breve, que o que modelos de aprendizado de máquinas (machine learning) mais fazem por nós é automatizar esse processo (se os entendermos, lógico).
#
# Neste caso, especificamente, queremos entender o efeito da variável `Gender` na distribuição dos dados.

# %% [markdown]
# ### Primeiro, plote a distribuição da variável `Height` de novo.

# %%
# Seu código aqui

# %% [markdown]
# ### Agora, filtre o dataset por gênero. Crie um dataframe chamado `homens` e outro chamado `mulheres` e plote a distribuição da altura para cada um (no mesmo gráfico).

# %%
# Seu código aqui

# %% [markdown]
# ### Quais observações você pode fazer a partir disso? Qual é o impacto de `Gender` em `Height`?

# %%
# Seu código aqui

# %% [markdown]
# **Extra:** Em https://github.com/mwaskom/seaborn/issues/861, há uma questão sobre distplot não ter argumento `hue` e como driblar isso (procure por `FacetGrid`).

# %% [markdown]
# Faça o mesmo para a variável `Money`. Qual é o impacto de `Gender` em `Money`?
#
# _Dica: para a variável dinheiro, tente especificar `hist = False`_

# %%
# Seu código aqui

# %% [markdown]
# ## Boxplot

# %% [markdown]
# ### Gênero versus Altura
#
# Plote o boxplot considerando o eixo x como `Gender` e o eixo y como `Height`.

# %%
plt.figure(figsize=(12, 8))
# Seu código aqui

# %% [markdown]
# ### Gênero versus Dinheiro

# %%
plt.figure(figsize=(12, 8))
# Seu código aqui

# %% [markdown]
# A partir das conclusões tiradas nos exercícios anteriores, você já esperava que esses resultados nos boxplots?

# %%
# Seu código aqui

# %% [markdown]
# ### Análise multivariada

# %% [markdown]
# Use `sns.pairplot` para ver algumas das combinações obtidas até agora. Use `hue = 'Gender'`.
#
# Perceba que, quanto mais colunas houver no dataset, mais confuso pode ficar o pairplot - use com sabedoria! (Muitas vezes, as pessoas só plotam esse gráfico e não tiram nenhuma conclusão a partir daí. Não caia nessa cilada!)

# %%
# Seu código aqui
